# %%
import socketserver
import threading
import os # os.path.getsize(path)
 
HOST = ''
PORT = 9100
lock = threading.Lock() # syncronized 동기화 진행하는 스레드 생성
 
class UserManager: # 사용자관리 및 채팅 메세지 전송을 담당하는 클래스
                   # ① 채팅 서버로 입장한 사용자의 등록
                   # ② 채팅을 종료하는 사용자의 퇴장 관리
                   # ③ 사용자가 입장하고 퇴장하는 관리
                   # ④ 사용자가 입력한 메세지를 채팅 서버에 접속한 모두에게 전송
 
    def __init__(self):
        self.users = {} # 사용자의 등록 정보를 담을 사전 {사용자 이름:(소켓,주소),...}
 
    def addUser(self, username, conn, addr): # 사용자 ID를 self.users에 추가하는 함수
        if username in self.users: # 이미 등록된 사용자라면
            conn.send('이미 등록된 사용자입니다.\n'.encode())
            return None
 
              # 새로운 사용자를 등록함
        lock.acquire() # 스레드 동기화를 막기위한 락
        self.users[username] = (conn, addr)
        lock.release() # 업데이트 후 락 해제

        self.sendMessageToAll('[%s]님이 입장했습니다. \n' %username)
        print('+++ 대화 참여자 수 [%d]' %len(self.users))

        return username
 
    def removeUser(self, username): #사용자를 제거하는 함수
        if username not in self.users:
            return

        lock.acquire()
        del self.users[username]
        lock.release()
 
        self.sendMessageToAll('[%s]님이 퇴장했습니다.' %username)
        print('--- 대화 참여자 수 [%d]' %len(self.users))
 
    def messageHandler(self, username, msg): # 전송한 msg를 처리하는 부분
        
        if msg.split('@')[0] == 'image_send_server_to_client':
            print('파일 전송 요청을 받았습니다 server -> client')
            file_name = msg.split('@')[1].strip()
            file_size = str(os.path.getsize(file_name))
            print('파일 이름 : ' + file_name)
            print('파일 길이 : ' + file_size)
            #if not exists(file_name): # 파일이 해당 디렉터리에 존재하지 않으면
            #    return # handle()함수를 빠져 나온다.
            self.sendMessageToAll('image_send_server_to_client@stoc_image.jpg@' + file_size + "\n")
            data_transferred = 0
            with open(file_name, 'rb') as f:
                try:
                    data = f.read(1024) # 파일을 1024바이트 읽음
                    while data: # 파일이 빈 문자열일때까지 반복
                        data_transferred += self.sendFileToAll(data)
                        #self.sendMessageToAll(msg)
                        data = f.read(1024)
                except Exception as e:
                    print(e)

            print('전송완료[%s], 전송량[%d]' %(file_name,data_transferred))
    
        else: #msg[0] != '/': # 보낸 메세지의 첫문자가 '/'가 아니면
            self.sendMessageToAll('[%s] %s' %(username, msg))
            return
 
        #if msg.strip() == '/quit': # 보낸 메세지가 'quit'이면
        #    self.removeUser(username)
        #    return -1
 
    def sendMessageToAll(self, msg):
        for conn, addr in self.users.values():
            print('뿌린 메시지 : ' + msg ,end='')
            conn.send(msg.encode())
    
    def sendFileToAll(self, msg):
        total = 0
        for conn, addr in self.users.values():
            print('전송중 : ' + str(msg))
            total += conn.send(msg)
        return total
    
           
 
class MyTcpHandler(socketserver.BaseRequestHandler):
    userman = UserManager()
     
    def handle(self): # 클라이언트가 접속시 클라이언트 주소 출력
        print('[%s] 연결됨' %self.client_address[0])
 
        try:
            username = self.registerUsername()
            msg = self.request.recv(1024)
            while msg:
                msg = msg.decode()
                if msg.split('@')[0] == 'image_send_client_to_server':
                    print('파일 전송 요청을 받았습니다 client -> server')
                    file_name = msg.split('@')[1].strip()
                    file_length_str = msg.split('@')[2].strip()
                    file_length_int = int(file_length_str)
                    print('파일 이름 : ' + file_name)
                    print('파일 길이 : ' + file_length_str)
                    file_size_count = 0
                   
                    with open(file_name, 'wb') as f:
                        try:
                            data = self.request.recv(1024)
                            while data:
                                #print('수신중 : ' + str(data))
                                file_size_count += f.write(data)
                                print('받은 데이터 길이 : ' + str(file_size_count))
                                if file_size_count >= file_length_int:
                                    break
                                data = self.request.recv(1024)
                            print('파일 수신 완료 : ' + str(file_size_count))
                        except Exception as e:
                            print(e)

                else: 
                    if self.userman.messageHandler(username, msg) == -1:
                        self.request.close()
                        break
                msg = self.request.recv(1024)
                 
        except Exception as e:
            print(e)
 
        print('[%s] 접속종료' %self.client_address[0])
        self.userman.removeUser(username)
 
    def registerUsername(self):
        while True:
            username = self.request.recv(1024)
            username = username.decode().strip()
            if self.userman.addUser(username, self.request, self.client_address):
                return username
 

class ChatingServer(socketserver.ThreadingMixIn, socketserver.TCPServer):
        pass
         
def runServer():
    print('+++ 채팅 서버를 시작합니다.')
    print('+++ 채팅 서버를 끝내려면 Ctrl-C를 누르세요.')
 
    try:
        server = ChatingServer((HOST, PORT), MyTcpHandler)
        server.serve_forever()
    except KeyboardInterrupt:
        print('--- 채팅 서버를 종료합니다.')
        server.shutdown()
        server.server_close()

        
runServer()
# Out:
# +++ 채팅 서버를 시작합니다.
# +++ 채팅 서버를 끝내려면 Ctrl-C를 누르세요.
# [192.168.0.6] 연결됨
# 뿌린 메시지 : [ㄴㅁ]님이 입장했습니다.
# +++ 대화 참여자 수 [1]
# 뿌린 메시지 : [ㄴㅁ]
# 파일 전송 요청을 받았습니다 client -> server
# 파일 이름 : ctos_image.jpg
# 파일 길이 : 700318
# 받은 데이터 길이 : 1024
# 받은 데이터 길이 : 2048
# 받은 데이터 길이 : 2920
# 받은 데이터 길이 : 3944
# 받은 데이터 길이 : 4968
# 받은 데이터 길이 : 5992
# 받은 데이터 길이 : 7016
# 받은 데이터 길이 : 8040
# 받은 데이터 길이 : 8760
# 받은 데이터 길이 : 9784
# 받은 데이터 길이 : 10808
# 받은 데이터 길이 : 11832
# 받은 데이터 길이 : 12856
# 받은 데이터 길이 : 13880
# 받은 데이터 길이 : 14904
# 받은 데이터 길이 : 15928
# 받은 데이터 길이 : 16060
# 받은 데이터 길이 : 17084
# 받은 데이터 길이 : 18108
# 받은 데이터 길이 : 19132
# 받은 데이터 길이 : 20156
# 받은 데이터 길이 : 21180
# 받은 데이터 길이 : 22204
# 받은 데이터 길이 : 23228
# 받은 데이터 길이 : 24252
# 받은 데이터 길이 : 24820
# 받은 데이터 길이 : 25844
# 받은 데이터 길이 : 26868
# 받은 데이터 길이 : 27892
# 받은 데이터 길이 : 28916
# 받은 데이터 길이 : 29940
# 받은 데이터 길이 : 30964
# 받은 데이터 길이 : 31988
# 받은 데이터 길이 : 33012
# 받은 데이터 길이 : 34036
# 받은 데이터 길이 : 35060
# 받은 데이터 길이 : 36084
# 받은 데이터 길이 : 36500
# 받은 데이터 길이 : 37524
# 받은 데이터 길이 : 38548
# 받은 데이터 길이 : 39572
# 받은 데이터 길이 : 40596
# 받은 데이터 길이 : 41620
# 받은 데이터 길이 : 42644
# 받은 데이터 길이 : 43668
# 받은 데이터 길이 : 44692
# 받은 데이터 길이 : 45716
# 받은 데이터 길이 : 46740
# 받은 데이터 길이 : 47764
# 받은 데이터 길이 : 48788
# 받은 데이터 길이 : 49640
# 받은 데이터 길이 : 50664
# 받은 데이터 길이 : 51100
# 받은 데이터 길이 : 52124
# 받은 데이터 길이 : 53148
# 받은 데이터 길이 : 54172
# 받은 데이터 길이 : 55196
# 받은 데이터 길이 : 56220
# 받은 데이터 길이 : 57244
# 받은 데이터 길이 : 58268
# 받은 데이터 길이 : 59292
# 받은 데이터 길이 : 60316
# 받은 데이터 길이 : 61340
# 받은 데이터 길이 : 62364
# 받은 데이터 길이 : 63388
# 받은 데이터 길이 : 64412
# 받은 데이터 길이 : 65436
# 받은 데이터 길이 : 66460
# 받은 데이터 길이 : 67484
# 받은 데이터 길이 : 68508
# 받은 데이터 길이 : 68620
# 받은 데이터 길이 : 69644
# 받은 데이터 길이 : 70668
# 받은 데이터 길이 : 71692
# 받은 데이터 길이 : 72716
# 받은 데이터 길이 : 73740
# 받은 데이터 길이 : 74764
# 받은 데이터 길이 : 75788
# 받은 데이터 길이 : 76812
# 받은 데이터 길이 : 77836
# 받은 데이터 길이 : 78860
# 받은 데이터 길이 : 79884
# 받은 데이터 길이 : 80908
# 받은 데이터 길이 : 81932
# 받은 데이터 길이 : 82956
# 받은 데이터 길이 : 83980
# 받은 데이터 길이 : 85004
# 받은 데이터 길이 : 86028
# 받은 데이터 길이 : 87052
# 받은 데이터 길이 : 88076
# 받은 데이터 길이 : 89100
# 받은 데이터 길이 : 90124
# 받은 데이터 길이 : 91148
# 받은 데이터 길이 : 92172
# 받은 데이터 길이 : 93196
# 받은 데이터 길이 : 93440
# 받은 데이터 길이 : 94464
# 받은 데이터 길이 : 95488
# 받은 데이터 길이 : 96512
# 받은 데이터 길이 : 97536
# 받은 데이터 길이 : 98560
# 받은 데이터 길이 : 99584
# 받은 데이터 길이 : 100608
# 받은 데이터 길이 : 101632
# 받은 데이터 길이 : 102656
# 받은 데이터 길이 : 103680
# 받은 데이터 길이 : 104704
# 받은 데이터 길이 : 105728
# 받은 데이터 길이 : 106752
# 받은 데이터 길이 : 107776
# 받은 데이터 길이 : 108800
# 받은 데이터 길이 : 109824
# 받은 데이터 길이 : 110848
# 받은 데이터 길이 : 110960
# 받은 데이터 길이 : 111984
# 받은 데이터 길이 : 113008
# 받은 데이터 길이 : 114032
# 받은 데이터 길이 : 115056
# 받은 데이터 길이 : 116080
# 받은 데이터 길이 : 117104
# 받은 데이터 길이 : 118128
# 받은 데이터 길이 : 119152
# 받은 데이터 길이 : 120176
# 받은 데이터 길이 : 121200
# 받은 데이터 길이 : 122224
# 받은 데이터 길이 : 123248
# 받은 데이터 길이 : 124272
# 받은 데이터 길이 : 125296
# 받은 데이터 길이 : 126320
# 받은 데이터 길이 : 127344
# 받은 데이터 길이 : 128368
# 받은 데이터 길이 : 129392
# 받은 데이터 길이 : 130416
# 받은 데이터 길이 : 131440
# 받은 데이터 길이 : 132464
# 받은 데이터 길이 : 133488
# 받은 데이터 길이 : 134512
# 받은 데이터 길이 : 135536
# 받은 데이터 길이 : 135780
# 받은 데이터 길이 : 136804
# 받은 데이터 길이 : 137828
# 받은 데이터 길이 : 138852
# 받은 데이터 길이 : 139876
# 받은 데이터 길이 : 140160
# 받은 데이터 길이 : 141184
# 받은 데이터 길이 : 142208
# 받은 데이터 길이 : 143232
# 받은 데이터 길이 : 144256
# 받은 데이터 길이 : 145280
# 받은 데이터 길이 : 146304
# 받은 데이터 길이 : 147328
# 받은 데이터 길이 : 148352
# 받은 데이터 길이 : 149376
# 받은 데이터 길이 : 150400
# 받은 데이터 길이 : 151424
# 받은 데이터 길이 : 152448
# 받은 데이터 길이 : 153300
# 받은 데이터 길이 : 154324
# 받은 데이터 길이 : 155348
# 받은 데이터 길이 : 156372
# 받은 데이터 길이 : 157396
# 받은 데이터 길이 : 158420
# 받은 데이터 길이 : 159444
# 받은 데이터 길이 : 160468
# 받은 데이터 길이 : 161492
# 받은 데이터 길이 : 162516
# 받은 데이터 길이 : 163540
# 받은 데이터 길이 : 164564
# 받은 데이터 길이 : 165588
# 받은 데이터 길이 : 166612
# 받은 데이터 길이 : 167636
# 받은 데이터 길이 : 168660
# 받은 데이터 길이 : 169684
# 받은 데이터 길이 : 170708
# 받은 데이터 길이 : 170820
# 받은 데이터 길이 : 171844
# 받은 데이터 길이 : 172868
# 받은 데이터 길이 : 173892
# 받은 데이터 길이 : 174916
# 받은 데이터 길이 : 175940
# 받은 데이터 길이 : 176964
# 받은 데이터 길이 : 177988
# 받은 데이터 길이 : 179012
# 받은 데이터 길이 : 180036
# 받은 데이터 길이 : 181060
# 받은 데이터 길이 : 182084
# 받은 데이터 길이 : 183108
# 받은 데이터 길이 : 184132
# 받은 데이터 길이 : 185156
# 받은 데이터 길이 : 186180
# 받은 데이터 길이 : 187204
# 받은 데이터 길이 : 188228
# 받은 데이터 길이 : 189252
# 받은 데이터 길이 : 190276
# 받은 데이터 길이 : 191300
# 받은 데이터 길이 : 192324
# 받은 데이터 길이 : 193348
# 받은 데이터 길이 : 194372
# 받은 데이터 길이 : 195396
# 받은 데이터 길이 : 196420
# 받은 데이터 길이 : 197444
# 받은 데이터 길이 : 198468
# 받은 데이터 길이 : 199492
# 받은 데이터 길이 : 200516
# 받은 데이터 길이 : 201540
# 받은 데이터 길이 : 202564
# 받은 데이터 길이 : 203588
# 받은 데이터 길이 : 204612
# 받은 데이터 길이 : 205636
# 받은 데이터 길이 : 206660
# 받은 데이터 길이 : 207684
# 받은 데이터 길이 : 208708
# 받은 데이터 길이 : 209732
# 받은 데이터 길이 : 210240
# 받은 데이터 길이 : 211264
# 받은 데이터 길이 : 211700
# 받은 데이터 길이 : 212724
# 받은 데이터 길이 : 213748
# 받은 데이터 길이 : 214772
# 받은 데이터 길이 : 215796
# 받은 데이터 길이 : 216820
# 받은 데이터 길이 : 217844
# 받은 데이터 길이 : 218868
# 받은 데이터 길이 : 219892
# 받은 데이터 길이 : 220916
# 받은 데이터 길이 : 221940
# 받은 데이터 길이 : 222964
# 받은 데이터 길이 : 223988
# 받은 데이터 길이 : 225012
# 받은 데이터 길이 : 226036
# 받은 데이터 길이 : 227060
# 받은 데이터 길이 : 228084
# 받은 데이터 길이 : 229108
# 받은 데이터 길이 : 230132
# 받은 데이터 길이 : 231156
# 받은 데이터 길이 : 232180
# 받은 데이터 길이 : 233204
# 받은 데이터 길이 : 234228
# 받은 데이터 길이 : 235252
# 받은 데이터 길이 : 236276
# 받은 데이터 길이 : 237300
# 받은 데이터 길이 : 238324
# 받은 데이터 길이 : 239348
# 받은 데이터 길이 : 240372
# 받은 데이터 길이 : 241396
# 받은 데이터 길이 : 242420
# 받은 데이터 길이 : 243444
# 받은 데이터 길이 : 244468
# 받은 데이터 길이 : 245492
# 받은 데이터 길이 : 246516
# 받은 데이터 길이 : 247540
# 받은 데이터 길이 : 248564
# 받은 데이터 길이 : 249588
# 받은 데이터 길이 : 250612
# 받은 데이터 길이 : 251636
# 받은 데이터 길이 : 252660
# 받은 데이터 길이 : 253684
# 받은 데이터 길이 : 254708
# 받은 데이터 길이 : 255732
# 받은 데이터 길이 : 256756
# 받은 데이터 길이 : 257780
# 받은 데이터 길이 : 258804
# 받은 데이터 길이 : 259828
# 받은 데이터 길이 : 260852
# 받은 데이터 길이 : 261876
# 받은 데이터 길이 : 262900
# 받은 데이터 길이 : 263924
# 받은 데이터 길이 : 264948
# 받은 데이터 길이 : 265972
# 받은 데이터 길이 : 266996
# 받은 데이터 길이 : 268020
# 받은 데이터 길이 : 269044
# 받은 데이터 길이 : 270068
# 받은 데이터 길이 : 271092
# 받은 데이터 길이 : 272116
# 받은 데이터 길이 : 273140
# 받은 데이터 길이 : 274164
# 받은 데이터 길이 : 275188
# 받은 데이터 길이 : 276212
# 받은 데이터 길이 : 277236
# 받은 데이터 길이 : 278260
# 받은 데이터 길이 : 279284
# 받은 데이터 길이 : 280308
# 받은 데이터 길이 : 281332
# 받은 데이터 길이 : 282356
# 받은 데이터 길이 : 283380
# 받은 데이터 길이 : 284404
# 받은 데이터 길이 : 285428
# 받은 데이터 길이 : 286452
# 받은 데이터 길이 : 287476
# 받은 데이터 길이 : 288500
# 받은 데이터 길이 : 289524
# 받은 데이터 길이 : 290548
# 받은 데이터 길이 : 291572
# 받은 데이터 길이 : 292596
# 받은 데이터 길이 : 293620
# 받은 데이터 길이 : 294644
# 받은 데이터 길이 : 295668
# 받은 데이터 길이 : 296692
# 받은 데이터 길이 : 297716
# 받은 데이터 길이 : 298740
# 받은 데이터 길이 : 299764
# 받은 데이터 길이 : 300788
# 받은 데이터 길이 : 301812
# 받은 데이터 길이 : 302836
# 받은 데이터 길이 : 303860
# 받은 데이터 길이 : 304884
# 받은 데이터 길이 : 305908
# 받은 데이터 길이 : 306932
# 받은 데이터 길이 : 307956
# 받은 데이터 길이 : 308980
# 받은 데이터 길이 : 310004
# 받은 데이터 길이 : 311028
# 받은 데이터 길이 : 312052
# 받은 데이터 길이 : 313076
# 받은 데이터 길이 : 314100
# 받은 데이터 길이 : 315124
# 받은 데이터 길이 : 316148
# 받은 데이터 길이 : 317172
# 받은 데이터 길이 : 318196
# 받은 데이터 길이 : 319220
# 받은 데이터 길이 : 320244
# 받은 데이터 길이 : 321268
# 받은 데이터 길이 : 322292
# 받은 데이터 길이 : 323316
# 받은 데이터 길이 : 324340
# 받은 데이터 길이 : 325364
# 받은 데이터 길이 : 326388
# 받은 데이터 길이 : 327412
# 받은 데이터 길이 : 328436
# 받은 데이터 길이 : 329460
# 받은 데이터 길이 : 330484
# 받은 데이터 길이 : 331508
# 받은 데이터 길이 : 332532
# 받은 데이터 길이 : 333556
# 받은 데이터 길이 : 334580
# 받은 데이터 길이 : 335604
# 받은 데이터 길이 : 336628
# 받은 데이터 길이 : 337652
# 받은 데이터 길이 : 338676
# 받은 데이터 길이 : 339700
# 받은 데이터 길이 : 340724
# 받은 데이터 길이 : 341748
# 받은 데이터 길이 : 342772
# 받은 데이터 길이 : 343796
# 받은 데이터 길이 : 344820
# 받은 데이터 길이 : 345844
# 받은 데이터 길이 : 346868
# 받은 데이터 길이 : 347892
# 받은 데이터 길이 : 348916
# 받은 데이터 길이 : 349940
# 받은 데이터 길이 : 350964
# 받은 데이터 길이 : 351988
# 받은 데이터 길이 : 353012
# 받은 데이터 길이 : 354036
# 받은 데이터 길이 : 355060
# 받은 데이터 길이 : 356084
# 받은 데이터 길이 : 357108
# 받은 데이터 길이 : 358132
# 받은 데이터 길이 : 359156
# 받은 데이터 길이 : 360180
# 받은 데이터 길이 : 361204
# 받은 데이터 길이 : 362228
# 받은 데이터 길이 : 363252
# 받은 데이터 길이 : 364276
# 받은 데이터 길이 : 365300
# 받은 데이터 길이 : 366324
# 받은 데이터 길이 : 367348
# 받은 데이터 길이 : 368372
# 받은 데이터 길이 : 369396
# 받은 데이터 길이 : 370420
# 받은 데이터 길이 : 371444
# 받은 데이터 길이 : 372468
# 받은 데이터 길이 : 373492
# 받은 데이터 길이 : 374516
# 받은 데이터 길이 : 375540
# 받은 데이터 길이 : 376564
# 받은 데이터 길이 : 377588
# 받은 데이터 길이 : 378612
# 받은 데이터 길이 : 379636
# 받은 데이터 길이 : 380660
# 받은 데이터 길이 : 381684
# 받은 데이터 길이 : 382708
# 받은 데이터 길이 : 383732
# 받은 데이터 길이 : 384756
# 받은 데이터 길이 : 385780
# 받은 데이터 길이 : 386804
# 받은 데이터 길이 : 387828
# 받은 데이터 길이 : 388852
# 받은 데이터 길이 : 389876
# 받은 데이터 길이 : 390900
# 받은 데이터 길이 : 391924
# 받은 데이터 길이 : 392948
# 받은 데이터 길이 : 393972
# 받은 데이터 길이 : 394996
# 받은 데이터 길이 : 396020
# 받은 데이터 길이 : 397044
# 받은 데이터 길이 : 398068
# 받은 데이터 길이 : 399092
# 받은 데이터 길이 : 400116
# 받은 데이터 길이 : 401140
# 받은 데이터 길이 : 402164
# 받은 데이터 길이 : 403188
# 받은 데이터 길이 : 404212
# 받은 데이터 길이 : 405236
# 받은 데이터 길이 : 406260
# 받은 데이터 길이 : 407284
# 받은 데이터 길이 : 408308
# 받은 데이터 길이 : 409332
# 받은 데이터 길이 : 410356
# 받은 데이터 길이 : 411380
# 받은 데이터 길이 : 412404
# 받은 데이터 길이 : 413428
# 받은 데이터 길이 : 414452
# 받은 데이터 길이 : 415476
# 받은 데이터 길이 : 416500
# 받은 데이터 길이 : 417524
# 받은 데이터 길이 : 418548
# 받은 데이터 길이 : 419572
# 받은 데이터 길이 : 420596
# 받은 데이터 길이 : 421620
# 받은 데이터 길이 : 422644
# 받은 데이터 길이 : 423668
# 받은 데이터 길이 : 424692
# 받은 데이터 길이 : 425716
# 받은 데이터 길이 : 426740
# 받은 데이터 길이 : 427764
# 받은 데이터 길이 : 428788
# 받은 데이터 길이 : 429812
# 받은 데이터 길이 : 430836
# 받은 데이터 길이 : 431860
# 받은 데이터 길이 : 432884
# 받은 데이터 길이 : 433908
# 받은 데이터 길이 : 434932
# 받은 데이터 길이 : 435956
# 받은 데이터 길이 : 436980
# 받은 데이터 길이 : 438004
# 받은 데이터 길이 : 439028
# 받은 데이터 길이 : 440052
# 받은 데이터 길이 : 441076
# 받은 데이터 길이 : 442100
# 받은 데이터 길이 : 443124
# 받은 데이터 길이 : 444148
# 받은 데이터 길이 : 445172
# 받은 데이터 길이 : 446196
# 받은 데이터 길이 : 447220
# 받은 데이터 길이 : 448244
# 받은 데이터 길이 : 449268
# 받은 데이터 길이 : 450292
# 받은 데이터 길이 : 451316
# 받은 데이터 길이 : 452340
# 받은 데이터 길이 : 453364
# 받은 데이터 길이 : 454388
# 받은 데이터 길이 : 455412
# 받은 데이터 길이 : 456436
# 받은 데이터 길이 : 457460
# 받은 데이터 길이 : 458484
# 받은 데이터 길이 : 459508
# 받은 데이터 길이 : 460532
# 받은 데이터 길이 : 461556
# 받은 데이터 길이 : 462580
# 받은 데이터 길이 : 463604
# 받은 데이터 길이 : 464628
# 받은 데이터 길이 : 465652
# 받은 데이터 길이 : 466676
# 받은 데이터 길이 : 467700
# 받은 데이터 길이 : 468724
# 받은 데이터 길이 : 469748
# 받은 데이터 길이 : 470772
# 받은 데이터 길이 : 471796
# 받은 데이터 길이 : 472820
# 받은 데이터 길이 : 473844
# 받은 데이터 길이 : 474868
# 받은 데이터 길이 : 475892
# 받은 데이터 길이 : 476916
# 받은 데이터 길이 : 477940
# 받은 데이터 길이 : 478964
# 받은 데이터 길이 : 479988
# 받은 데이터 길이 : 481012
# 받은 데이터 길이 : 482036
# 받은 데이터 길이 : 483060
# 받은 데이터 길이 : 484084
# 받은 데이터 길이 : 485108
# 받은 데이터 길이 : 486132
# 받은 데이터 길이 : 487156
# 받은 데이터 길이 : 488180
# 받은 데이터 길이 : 489204
# 받은 데이터 길이 : 490228
# 받은 데이터 길이 : 491252
# 받은 데이터 길이 : 492276
# 받은 데이터 길이 : 493300
# 받은 데이터 길이 : 494324
# 받은 데이터 길이 : 495348
# 받은 데이터 길이 : 496372
# 받은 데이터 길이 : 497396
# 받은 데이터 길이 : 498420
# 받은 데이터 길이 : 499444
# 받은 데이터 길이 : 500468
# 받은 데이터 길이 : 501492
# 받은 데이터 길이 : 502516
# 받은 데이터 길이 : 503540
# 받은 데이터 길이 : 504564
# 받은 데이터 길이 : 505588
# 받은 데이터 길이 : 506612
# 받은 데이터 길이 : 507636
# 받은 데이터 길이 : 508660
# 받은 데이터 길이 : 509684
# 받은 데이터 길이 : 510708
# 받은 데이터 길이 : 511732
# 받은 데이터 길이 : 512756
# 받은 데이터 길이 : 513780
# 받은 데이터 길이 : 514804
# 받은 데이터 길이 : 515828
# 받은 데이터 길이 : 516852
# 받은 데이터 길이 : 517876
# 받은 데이터 길이 : 518900
# 받은 데이터 길이 : 519924
# 받은 데이터 길이 : 520948
# 받은 데이터 길이 : 521972
# 받은 데이터 길이 : 522996
# 받은 데이터 길이 : 524020
# 받은 데이터 길이 : 525044
# 받은 데이터 길이 : 526068
# 받은 데이터 길이 : 527092
# 받은 데이터 길이 : 528116
# 받은 데이터 길이 : 529140
# 받은 데이터 길이 : 530164
# 받은 데이터 길이 : 531188
# 받은 데이터 길이 : 532212
# 받은 데이터 길이 : 533236
# 받은 데이터 길이 : 534260
# 받은 데이터 길이 : 535284
# 받은 데이터 길이 : 536308
# 받은 데이터 길이 : 537332
# 받은 데이터 길이 : 538356
# 받은 데이터 길이 : 539380
# 받은 데이터 길이 : 540404
# 받은 데이터 길이 : 541428
# 받은 데이터 길이 : 542452
# 받은 데이터 길이 : 543476
# 받은 데이터 길이 : 544500
# 받은 데이터 길이 : 545524
# 받은 데이터 길이 : 546548
# 받은 데이터 길이 : 547572
# 받은 데이터 길이 : 548596
# 받은 데이터 길이 : 549620
# 받은 데이터 길이 : 550644
# 받은 데이터 길이 : 551668
# 받은 데이터 길이 : 552692
# 받은 데이터 길이 : 553716
# 받은 데이터 길이 : 554740
# 받은 데이터 길이 : 555764
# 받은 데이터 길이 : 556788
# 받은 데이터 길이 : 557812
# 받은 데이터 길이 : 558836
# 받은 데이터 길이 : 559860
# 받은 데이터 길이 : 560884
# 받은 데이터 길이 : 561908
# 받은 데이터 길이 : 562932
# 받은 데이터 길이 : 563956
# 받은 데이터 길이 : 564980
# 받은 데이터 길이 : 566004
# 받은 데이터 길이 : 567028
# 받은 데이터 길이 : 568052
# 받은 데이터 길이 : 569076
# 받은 데이터 길이 : 570100
# 받은 데이터 길이 : 571124
# 받은 데이터 길이 : 572148
# 받은 데이터 길이 : 573172
# 받은 데이터 길이 : 574196
# 받은 데이터 길이 : 575220
# 받은 데이터 길이 : 576244
# 받은 데이터 길이 : 577268
# 받은 데이터 길이 : 578292
# 받은 데이터 길이 : 579316
# 받은 데이터 길이 : 580340
# 받은 데이터 길이 : 581364
# 받은 데이터 길이 : 582388
# 받은 데이터 길이 : 583412
# 받은 데이터 길이 : 584436
# 받은 데이터 길이 : 585460
# 받은 데이터 길이 : 586484
# 받은 데이터 길이 : 587508
# 받은 데이터 길이 : 588532
# 받은 데이터 길이 : 589556
# 받은 데이터 길이 : 590580
# 받은 데이터 길이 : 591604
# 받은 데이터 길이 : 592628
# 받은 데이터 길이 : 593652
# 받은 데이터 길이 : 594676
# 받은 데이터 길이 : 595700
# 받은 데이터 길이 : 596724
# 받은 데이터 길이 : 597748
# 받은 데이터 길이 : 598772
# 받은 데이터 길이 : 599796
# 받은 데이터 길이 : 600820
# 받은 데이터 길이 : 601844
# 받은 데이터 길이 : 602868
# 받은 데이터 길이 : 603892
# 받은 데이터 길이 : 604916
# 받은 데이터 길이 : 605940
# 받은 데이터 길이 : 606964
# 받은 데이터 길이 : 607988
# 받은 데이터 길이 : 609012
# 받은 데이터 길이 : 610036
# 받은 데이터 길이 : 611060
# 받은 데이터 길이 : 612084
# 받은 데이터 길이 : 613108
# 받은 데이터 길이 : 614132
# 받은 데이터 길이 : 615156
# 받은 데이터 길이 : 616180
# 받은 데이터 길이 : 617204
# 받은 데이터 길이 : 618228
# 받은 데이터 길이 : 619252
# 받은 데이터 길이 : 620276
# 받은 데이터 길이 : 621300
# 받은 데이터 길이 : 622324
# 받은 데이터 길이 : 623348
# 받은 데이터 길이 : 624372
# 받은 데이터 길이 : 625396
# 받은 데이터 길이 : 626420
# 받은 데이터 길이 : 627444
# 받은 데이터 길이 : 628468
# 받은 데이터 길이 : 629492
# 받은 데이터 길이 : 630516
# 받은 데이터 길이 : 631540
# 받은 데이터 길이 : 632564
# 받은 데이터 길이 : 633588
# 받은 데이터 길이 : 634612
# 받은 데이터 길이 : 635636
# 받은 데이터 길이 : 636660
# 받은 데이터 길이 : 637684
# 받은 데이터 길이 : 638708
# 받은 데이터 길이 : 639732
# 받은 데이터 길이 : 640756
# 받은 데이터 길이 : 641780
# 받은 데이터 길이 : 642804
# 받은 데이터 길이 : 643828
# 받은 데이터 길이 : 644852
# 받은 데이터 길이 : 645876
# 받은 데이터 길이 : 646900
# 받은 데이터 길이 : 647924
# 받은 데이터 길이 : 648948
# 받은 데이터 길이 : 649972
# 받은 데이터 길이 : 650996
# 받은 데이터 길이 : 652020
# 받은 데이터 길이 : 653044
# 받은 데이터 길이 : 654068
# 받은 데이터 길이 : 655092
# 받은 데이터 길이 : 656116
# 받은 데이터 길이 : 657140
# 받은 데이터 길이 : 658164
# 받은 데이터 길이 : 659188
# 받은 데이터 길이 : 660212
# 받은 데이터 길이 : 661236
# 받은 데이터 길이 : 662260
# 받은 데이터 길이 : 663284
# 받은 데이터 길이 : 664308
# 받은 데이터 길이 : 665332
# 받은 데이터 길이 : 666356
# 받은 데이터 길이 : 667380
# 받은 데이터 길이 : 668404
# 받은 데이터 길이 : 669428
# 받은 데이터 길이 : 670452
# 받은 데이터 길이 : 671476
# 받은 데이터 길이 : 672500
# 받은 데이터 길이 : 673524
# 받은 데이터 길이 : 674548
# 받은 데이터 길이 : 675572
# 받은 데이터 길이 : 676596
# 받은 데이터 길이 : 677620
# 받은 데이터 길이 : 678644
# 받은 데이터 길이 : 679668
# 받은 데이터 길이 : 680692
# 받은 데이터 길이 : 681716
# 받은 데이터 길이 : 682740
# 받은 데이터 길이 : 683764
# 받은 데이터 길이 : 684788
# 받은 데이터 길이 : 685812
# 받은 데이터 길이 : 686836
# 받은 데이터 길이 : 687860
# 받은 데이터 길이 : 688884
# 받은 데이터 길이 : 689908
# 받은 데이터 길이 : 690932
# 받은 데이터 길이 : 691956
# 받은 데이터 길이 : 692980
# 받은 데이터 길이 : 694004
# 받은 데이터 길이 : 695028
# 받은 데이터 길이 : 696052
# 받은 데이터 길이 : 697076
# 받은 데이터 길이 : 698100
# 받은 데이터 길이 : 699124
# 받은 데이터 길이 : 700148
# 받은 데이터 길이 : 700416
# 파일 수신 완료 : 700416
# 뿌린 메시지 : [ㄴㅁ]
# 파일 전송 요청을 받았습니다 server -> client
# 파일 이름 : stoc_image.jpg
# 파일 길이 : 4720
# 뿌린 메시지 : image_send_server_to_client@stoc_image.jpg@4720
# 전송중 : b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\t\x06\x07\x13\x12\x12\x15\x12\x12\x12\x12\x15\x10\x12\x15\x12\x15\x16\x10\x15\x15\x10\x15\x15\x10\x15\x15\x12\x16\x16\x15\x15\x15\x15\x18\x1d( \x18\x1a%\x1b\x15\x15!1!%)+...\x17\x1f3:3-7(9.+\x01\n\n\n\x0e\r\x0e\x1a\x10\x10\x17+\x1d\x1d\x1d-.---+-+---------+-.---------++-------------------\xff\xc0\x00\x11\x08\x00\xb4\x01\x17\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x00\x03\x00\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x04\x06\x07\x05\x03\x08\xff\xc4\x00I\x10\x00\x02\x01\x02\x03\x05\x05\x05\x03\x07\x08\n\x03\x00\x00\x00\x00\x01\x02\x03\x11\x04\x121\x05!AQa\x07\x13q\x81\x91\x06\xa1\xb1\xc1\xf0\x14"\xd1\x15#2rs\xb4\xf1BR\x82\x84\x93\xb2\xb3\xe1$%&56CTt\xc2\xd2\x1734\xff\xc4\x00\x1a\x01\x01\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\xff\xc4\x00)\x11\x01\x00\x02\x01\x03\x03\x03\x04\x02\x03\x00\x00\x00\x00\x00\x00\x00\x01\x02\x11\x03\x04!\x121A\x052Q"aq\xb1\x81\xf0#$3\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xe6\x04\xbf\x9a(\x9f\xc5\x1e\xc7\x8dQ\xd0M\xff\x00\x01\xc4"\xb5\x08^\x81\xe6\x8a\x17\x90\x02\x04\xc1\xb6\x17\xf0\x00}E\xf81\xdf\xc0w\xf0\x00w\xe8\x1c\x87\xe25\x10\x89Kp\xd3\xf1\x1ct%X\x07\x98\x12\xf1\xf0\r\xdfH"\xd1A.#\xe3\xb8-\xbcj!\x02\x88\xd8\xc1\xa0\x04\xc9\x94JH$\x80\x14A\xb0\xccK\x7f \x8aL\xa2 \x8al\xa2d8\x83h"\xd0S\xe3\xe4\x1cE\x9bxI\xa0\x87\x12|\xfd\xfa\x96\xa4\x89m} )-\xc1\xbci\xa2\x8a\x89O\x98\x05M\x00\x0ck\x92\xfec\xb7\x805\xf10\xe8p\xd0#\xc7\xc4#\xa0\xe2\x00\xd8D\x99\xa1\xd3@4\'\xa9Q\x17?\x10\x82_\x01\xc8O\x89`+\\"\xc2:\x04\n%"\x92_W!\xe8\x8a\xa6\x00\xa2NS\xe9\x1e>#\xca\x110_"\xc4\xb5\xf4(\x00\x95r\x85\x1d\x02\x08\xb0\x08\xfe!\x1f\x9b("5\xab\xf2\x05\x
# 전송완료[stoc_image.jpg], 전송량[4720]
# 파일 전송 요청을 받았습니다 client -> server
# 파일 이름 : ctos_image.jpg
# 파일 길이 : 700318
# 받은 데이터 길이 : 1024
# 받은 데이터 길이 : 2048
# 받은 데이터 길이 : 3072
# 받은 데이터 길이 : 4096
# 받은 데이터 길이 : 5120
# 받은 데이터 길이 : 6144
# 받은 데이터 길이 : 7168
# 받은 데이터 길이 : 8192
# 받은 데이터 길이 : 9216
# 받은 데이터 길이 : 10240
# 받은 데이터 길이 : 11264
# 받은 데이터 길이 : 12288
# 받은 데이터 길이 : 13312
# 받은 데이터 길이 : 14336
# 받은 데이터 길이 : 15360
# 받은 데이터 길이 : 16384
# 받은 데이터 길이 : 17408
# 받은 데이터 길이 : 18432
# 받은 데이터 길이 : 19456
# 받은 데이터 길이 : 20480
# 받은 데이터 길이 : 21504
# 받은 데이터 길이 : 22528
# 받은 데이터 길이 : 23552
# 받은 데이터 길이 : 24576
# 받은 데이터 길이 : 25600
# 받은 데이터 길이 : 26624
# 받은 데이터 길이 : 27648
# 받은 데이터 길이 : 28672
# 받은 데이터 길이 : 29696
# 받은 데이터 길이 : 30720
# 받은 데이터 길이 : 31744
# 받은 데이터 길이 : 32768
# 받은 데이터 길이 : 33792
# 받은 데이터 길이 : 34816
# 받은 데이터 길이 : 35840
# 받은 데이터 길이 : 36864
# 받은 데이터 길이 : 37888
# 받은 데이터 길이 : 38912
# 받은 데이터 길이 : 39936
# 받은 데이터 길이 : 40960
# 받은 데이터 길이 : 41984
# 받은 데이터 길이 : 43008
# 받은 데이터 길이 : 44032
# 받은 데이터 길이 : 45056
# 받은 데이터 길이 : 46080
# 받은 데이터 길이 : 46720
# 받은 데이터 길이 : 47744
# 받은 데이터 길이 : 48768
# 받은 데이터 길이 : 49792
# 받은 데이터 길이 : 50816
# 받은 데이터 길이 : 51840
# 받은 데이터 길이 : 52864
# 받은 데이터 길이 : 53888
# 받은 데이터 길이 : 54912
# 받은 데이터 길이 : 55936
# 받은 데이터 길이 : 56960
# 받은 데이터 길이 : 57984
# 받은 데이터 길이 : 59008
# 받은 데이터 길이 : 60032
# 받은 데이터 길이 : 61056
# 받은 데이터 길이 : 62080
# 받은 데이터 길이 : 63104
# 받은 데이터 길이 : 64128
# 받은 데이터 길이 : 65152
# 받은 데이터 길이 : 66176
# 받은 데이터 길이 : 67200
# 받은 데이터 길이 : 68224
# 받은 데이터 길이 : 69248
# 받은 데이터 길이 : 70272
# 받은 데이터 길이 : 71296
# 받은 데이터 길이 : 72320
# 받은 데이터 길이 : 73344
# 받은 데이터 길이 : 74368
# 받은 데이터 길이 : 75392
# 받은 데이터 길이 : 76416
# 받은 데이터 길이 : 77440
# 받은 데이터 길이 : 78464
# 받은 데이터 길이 : 79488
# 받은 데이터 길이 : 80512
# 받은 데이터 길이 : 81536
# 받은 데이터 길이 : 82560
# 받은 데이터 길이 : 83584
# 받은 데이터 길이 : 84608
# 받은 데이터 길이 : 85632
# 받은 데이터 길이 : 86656
# 받은 데이터 길이 : 87680
# 받은 데이터 길이 : 88704
# 받은 데이터 길이 : 89728
# 받은 데이터 길이 : 90752
# 받은 데이터 길이 : 91776
# 받은 데이터 길이 : 92800
# 받은 데이터 길이 : 93824
# 받은 데이터 길이 : 94848
# 받은 데이터 길이 : 95872
# 받은 데이터 길이 : 96896
# 받은 데이터 길이 : 97920
# 받은 데이터 길이 : 98944
# 받은 데이터 길이 : 99968
# 받은 데이터 길이 : 100992
# 받은 데이터 길이 : 102016
# 받은 데이터 길이 : 103040
# 받은 데이터 길이 : 104064
# 받은 데이터 길이 : 105088
# 받은 데이터 길이 : 106112
# 받은 데이터 길이 : 107136
# 받은 데이터 길이 : 108160
# 받은 데이터 길이 : 109184
# 받은 데이터 길이 : 110208
# 받은 데이터 길이 : 111232
# 받은 데이터 길이 : 112256
# 받은 데이터 길이 : 113280
# 받은 데이터 길이 : 114304
# 받은 데이터 길이 : 115328
# 받은 데이터 길이 : 116352
# 받은 데이터 길이 : 117376
# 받은 데이터 길이 : 118400
# 받은 데이터 길이 : 119424
# 받은 데이터 길이 : 120448
# 받은 데이터 길이 : 121472
# 받은 데이터 길이 : 122496
# 받은 데이터 길이 : 123520
# 받은 데이터 길이 : 124544
# 받은 데이터 길이 : 125568
# 받은 데이터 길이 : 126592
# 받은 데이터 길이 : 127616
# 받은 데이터 길이 : 128640
# 받은 데이터 길이 : 129664
# 받은 데이터 길이 : 130688
# 받은 데이터 길이 : 131712
# 받은 데이터 길이 : 132736
# 받은 데이터 길이 : 133760
# 받은 데이터 길이 : 134784
# 받은 데이터 길이 : 135808
# 받은 데이터 길이 : 136832
# 받은 데이터 길이 : 137856
# 받은 데이터 길이 : 138880
# 받은 데이터 길이 : 139904
# 받은 데이터 길이 : 140928
# 받은 데이터 길이 : 141952
# 받은 데이터 길이 : 142976
# 받은 데이터 길이 : 144000
# 받은 데이터 길이 : 145024
# 받은 데이터 길이 : 146048
# 받은 데이터 길이 : 147072
# 받은 데이터 길이 : 148096
# 받은 데이터 길이 : 149120
# 받은 데이터 길이 : 150144
# 받은 데이터 길이 : 151168
# 받은 데이터 길이 : 152192
# 받은 데이터 길이 : 153216
# 받은 데이터 길이 : 154240
# 받은 데이터 길이 : 155264
# 받은 데이터 길이 : 156288
# 받은 데이터 길이 : 157312
# 받은 데이터 길이 : 158336
# 받은 데이터 길이 : 159360
# 받은 데이터 길이 : 160384
# 받은 데이터 길이 : 161408
# 받은 데이터 길이 : 162432
# 받은 데이터 길이 : 163456
# 받은 데이터 길이 : 164480
# 받은 데이터 길이 : 165504
# 받은 데이터 길이 : 166528
# 받은 데이터 길이 : 167552
# 받은 데이터 길이 : 168576
# 받은 데이터 길이 : 169600
# 받은 데이터 길이 : 170624
# 받은 데이터 길이 : 171648
# 받은 데이터 길이 : 172672
# 받은 데이터 길이 : 173696
# 받은 데이터 길이 : 174720
# 받은 데이터 길이 : 175744
# 받은 데이터 길이 : 176768
# 받은 데이터 길이 : 177792
# 받은 데이터 길이 : 178816
# 받은 데이터 길이 : 179840
# 받은 데이터 길이 : 180864
# 받은 데이터 길이 : 181888
# 받은 데이터 길이 : 182912
# 받은 데이터 길이 : 183936
# 받은 데이터 길이 : 184960
# 받은 데이터 길이 : 185984
# 받은 데이터 길이 : 187008
# 받은 데이터 길이 : 188032
# 받은 데이터 길이 : 189056
# 받은 데이터 길이 : 190080
# 받은 데이터 길이 : 191104
# 받은 데이터 길이 : 192128
# 받은 데이터 길이 : 193152
# 받은 데이터 길이 : 194176
# 받은 데이터 길이 : 195200
# 받은 데이터 길이 : 196224
# 받은 데이터 길이 : 197248
# 받은 데이터 길이 : 198272
# 받은 데이터 길이 : 199296
# 받은 데이터 길이 : 200320
# 받은 데이터 길이 : 201344
# 받은 데이터 길이 : 202368
# 받은 데이터 길이 : 203392
# 받은 데이터 길이 : 204416
# 받은 데이터 길이 : 205440
# 받은 데이터 길이 : 206464
# 받은 데이터 길이 : 207488
# 받은 데이터 길이 : 208512
# 받은 데이터 길이 : 209536
# 받은 데이터 길이 : 210560
# 받은 데이터 길이 : 211584
# 받은 데이터 길이 : 212608
# 받은 데이터 길이 : 213632
# 받은 데이터 길이 : 214656
# 받은 데이터 길이 : 215680
# 받은 데이터 길이 : 216704
# 받은 데이터 길이 : 217728
# 받은 데이터 길이 : 218752
# 받은 데이터 길이 : 219776
# 받은 데이터 길이 : 220800
# 받은 데이터 길이 : 221824
# 받은 데이터 길이 : 222848
# 받은 데이터 길이 : 223872
# 받은 데이터 길이 : 224896
# 받은 데이터 길이 : 225920
# 받은 데이터 길이 : 226944
# 받은 데이터 길이 : 227968
# 받은 데이터 길이 : 228992
# 받은 데이터 길이 : 230016
# 받은 데이터 길이 : 231040
# 받은 데이터 길이 : 232064
# 받은 데이터 길이 : 233088
# 받은 데이터 길이 : 234112
# 받은 데이터 길이 : 235136
# 받은 데이터 길이 : 236160
# 받은 데이터 길이 : 237184
# 받은 데이터 길이 : 238208
# 받은 데이터 길이 : 239232
# 받은 데이터 길이 : 240256
# 받은 데이터 길이 : 241280
# 받은 데이터 길이 : 242304
# 받은 데이터 길이 : 243328
# 받은 데이터 길이 : 244352
# 받은 데이터 길이 : 245376
# 받은 데이터 길이 : 246400
# 받은 데이터 길이 : 247424
# 받은 데이터 길이 : 248448
# 받은 데이터 길이 : 249472
# 받은 데이터 길이 : 250496
# 받은 데이터 길이 : 251520
# 받은 데이터 길이 : 252544
# 받은 데이터 길이 : 253568
# 받은 데이터 길이 : 254592
# 받은 데이터 길이 : 255616
# 받은 데이터 길이 : 256640
# 받은 데이터 길이 : 257664
# 받은 데이터 길이 : 258688
# 받은 데이터 길이 : 259712
# 받은 데이터 길이 : 260736
# 받은 데이터 길이 : 261760
# 받은 데이터 길이 : 262784
# 받은 데이터 길이 : 263808
# 받은 데이터 길이 : 264832
# 받은 데이터 길이 : 265856
# 받은 데이터 길이 : 266880
# 받은 데이터 길이 : 267904
# 받은 데이터 길이 : 268928
# 받은 데이터 길이 : 269952
# 받은 데이터 길이 : 270976
# 받은 데이터 길이 : 272000
# 받은 데이터 길이 : 273024
# 받은 데이터 길이 : 274048
# 받은 데이터 길이 : 275072
# 받은 데이터 길이 : 276096
# 받은 데이터 길이 : 277120
# 받은 데이터 길이 : 278144
# 받은 데이터 길이 : 279168
# 받은 데이터 길이 : 280192
# 받은 데이터 길이 : 281216
# 받은 데이터 길이 : 282240
# 받은 데이터 길이 : 283264
# 받은 데이터 길이 : 284288
# 받은 데이터 길이 : 285312
# 받은 데이터 길이 : 286336
# 받은 데이터 길이 : 287360
# 받은 데이터 길이 : 288384
# 받은 데이터 길이 : 289408
# 받은 데이터 길이 : 290432
# 받은 데이터 길이 : 290540
# 받은 데이터 길이 : 291564
# 받은 데이터 길이 : 292588
# 받은 데이터 길이 : 293612
# 받은 데이터 길이 : 294636
# 받은 데이터 길이 : 295660
# 받은 데이터 길이 : 296684
# 받은 데이터 길이 : 297708
# 받은 데이터 길이 : 298732
# 받은 데이터 길이 : 299756
# 받은 데이터 길이 : 300780
# 받은 데이터 길이 : 301804
# 받은 데이터 길이 : 302828
# 받은 데이터 길이 : 303852
# 받은 데이터 길이 : 304876
# 받은 데이터 길이 : 305900
# 받은 데이터 길이 : 306924
# 받은 데이터 길이 : 307948
# 받은 데이터 길이 : 308972
# 받은 데이터 길이 : 309996
# 받은 데이터 길이 : 311020
# 받은 데이터 길이 : 312044
# 받은 데이터 길이 : 313068
# 받은 데이터 길이 : 314092
# 받은 데이터 길이 : 315116
# 받은 데이터 길이 : 316140
# 받은 데이터 길이 : 317164
# 받은 데이터 길이 : 318188
# 받은 데이터 길이 : 319212
# 받은 데이터 길이 : 320236
# 받은 데이터 길이 : 321260
# 받은 데이터 길이 : 322284
# 받은 데이터 길이 : 323308
# 받은 데이터 길이 : 324332
# 받은 데이터 길이 : 325356
# 받은 데이터 길이 : 326380
# 받은 데이터 길이 : 327404
# 받은 데이터 길이 : 328428
# 받은 데이터 길이 : 329452
# 받은 데이터 길이 : 330476
# 받은 데이터 길이 : 331500
# 받은 데이터 길이 : 332524
# 받은 데이터 길이 : 333548
# 받은 데이터 길이 : 334572
# 받은 데이터 길이 : 335596
# 받은 데이터 길이 : 336620
# 받은 데이터 길이 : 337644
# 받은 데이터 길이 : 338668
# 받은 데이터 길이 : 339692
# 받은 데이터 길이 : 340716
# 받은 데이터 길이 : 341740
# 받은 데이터 길이 : 342764
# 받은 데이터 길이 : 343788
# 받은 데이터 길이 : 344812
# 받은 데이터 길이 : 345836
# 받은 데이터 길이 : 346860
# 받은 데이터 길이 : 347884
# 받은 데이터 길이 : 348908
# 받은 데이터 길이 : 349932
# 받은 데이터 길이 : 350956
# 받은 데이터 길이 : 351980
# 받은 데이터 길이 : 353004
# 받은 데이터 길이 : 354028
# 받은 데이터 길이 : 355052
# 받은 데이터 길이 : 356076
# 받은 데이터 길이 : 357100
# 받은 데이터 길이 : 358124
# 받은 데이터 길이 : 359148
# 받은 데이터 길이 : 360172
# 받은 데이터 길이 : 361196
# 받은 데이터 길이 : 362220
# 받은 데이터 길이 : 363244
# 받은 데이터 길이 : 364268
# 받은 데이터 길이 : 365292
# 받은 데이터 길이 : 366316
# 받은 데이터 길이 : 367340
# 받은 데이터 길이 : 368364
# 받은 데이터 길이 : 369388
# 받은 데이터 길이 : 370412
# 받은 데이터 길이 : 371436
# 받은 데이터 길이 : 372460
# 받은 데이터 길이 : 373484
# 받은 데이터 길이 : 374508
# 받은 데이터 길이 : 375532
# 받은 데이터 길이 : 376556
# 받은 데이터 길이 : 377580
# 받은 데이터 길이 : 378604
# 받은 데이터 길이 : 379628
# 받은 데이터 길이 : 380652
# 받은 데이터 길이 : 381676
# 받은 데이터 길이 : 382700
# 받은 데이터 길이 : 383724
# 받은 데이터 길이 : 384748
# 받은 데이터 길이 : 385772
# 받은 데이터 길이 : 386796
# 받은 데이터 길이 : 387820
# 받은 데이터 길이 : 388844
# 받은 데이터 길이 : 389868
# 받은 데이터 길이 : 390892
# 받은 데이터 길이 : 391916
# 받은 데이터 길이 : 392940
# 받은 데이터 길이 : 393964
# 받은 데이터 길이 : 394988
# 받은 데이터 길이 : 396012
# 받은 데이터 길이 : 397036
# 받은 데이터 길이 : 398060
# 받은 데이터 길이 : 399084
# 받은 데이터 길이 : 400108
# 받은 데이터 길이 : 401132
# 받은 데이터 길이 : 402156
# 받은 데이터 길이 : 403180
# 받은 데이터 길이 : 404204
# 받은 데이터 길이 : 405228
# 받은 데이터 길이 : 406252
# 받은 데이터 길이 : 407276
# 받은 데이터 길이 : 408300
# 받은 데이터 길이 : 409324
# 받은 데이터 길이 : 410348
# 받은 데이터 길이 : 411372
# 받은 데이터 길이 : 412396
# 받은 데이터 길이 : 413420
# 받은 데이터 길이 : 414444
# 받은 데이터 길이 : 415468
# 받은 데이터 길이 : 416492
# 받은 데이터 길이 : 417516
# 받은 데이터 길이 : 418540
# 받은 데이터 길이 : 419564
# 받은 데이터 길이 : 420588
# 받은 데이터 길이 : 421612
# 받은 데이터 길이 : 422636
# 받은 데이터 길이 : 423660
# 받은 데이터 길이 : 424684
# 받은 데이터 길이 : 425708
# 받은 데이터 길이 : 426732
# 받은 데이터 길이 : 427756
# 받은 데이터 길이 : 428780
# 받은 데이터 길이 : 429804
# 받은 데이터 길이 : 430828
# 받은 데이터 길이 : 431852
# 받은 데이터 길이 : 432876
# 받은 데이터 길이 : 433900
# 받은 데이터 길이 : 434924
# 받은 데이터 길이 : 435948
# 받은 데이터 길이 : 436972
# 받은 데이터 길이 : 437996
# 받은 데이터 길이 : 439020
# 받은 데이터 길이 : 440044
# 받은 데이터 길이 : 441068
# 받은 데이터 길이 : 442092
# 받은 데이터 길이 : 443116
# 받은 데이터 길이 : 444140
# 받은 데이터 길이 : 445164
# 받은 데이터 길이 : 446188
# 받은 데이터 길이 : 447212
# 받은 데이터 길이 : 448220
# 받은 데이터 길이 : 449244
# 받은 데이터 길이 : 449680
# 받은 데이터 길이 : 450704
# 받은 데이터 길이 : 451728
# 받은 데이터 길이 : 452752
# 받은 데이터 길이 : 453776
# 받은 데이터 길이 : 454800
# 받은 데이터 길이 : 455824
# 받은 데이터 길이 : 456848
# 받은 데이터 길이 : 457872
# 받은 데이터 길이 : 458896
# 받은 데이터 길이 : 459920
# 받은 데이터 길이 : 460944
# 받은 데이터 길이 : 461968
# 받은 데이터 길이 : 462992
# 받은 데이터 길이 : 464016
# 받은 데이터 길이 : 465040
# 받은 데이터 길이 : 466064
# 받은 데이터 길이 : 467088
# 받은 데이터 길이 : 468112
# 받은 데이터 길이 : 469136
# 받은 데이터 길이 : 470160
# 받은 데이터 길이 : 471184
# 받은 데이터 길이 : 472208
# 받은 데이터 길이 : 473232
# 받은 데이터 길이 : 474256
# 받은 데이터 길이 : 475280
# 받은 데이터 길이 : 476304
# 받은 데이터 길이 : 477328
# 받은 데이터 길이 : 478352
# 받은 데이터 길이 : 479376
# 받은 데이터 길이 : 480400
# 받은 데이터 길이 : 481424
# 받은 데이터 길이 : 482448
# 받은 데이터 길이 : 483472
# 받은 데이터 길이 : 484496
# 받은 데이터 길이 : 485520
# 받은 데이터 길이 : 486544
# 받은 데이터 길이 : 487568
# 받은 데이터 길이 : 488592
# 받은 데이터 길이 : 489616
# 받은 데이터 길이 : 490640
# 받은 데이터 길이 : 491664
# 받은 데이터 길이 : 492688
# 받은 데이터 길이 : 493712
# 받은 데이터 길이 : 494736
# 받은 데이터 길이 : 495760
# 받은 데이터 길이 : 496784
# 받은 데이터 길이 : 497808
# 받은 데이터 길이 : 498832
# 받은 데이터 길이 : 499856
# 받은 데이터 길이 : 500880
# 받은 데이터 길이 : 501904
# 받은 데이터 길이 : 502928
# 받은 데이터 길이 : 503952
# 받은 데이터 길이 : 504976
# 받은 데이터 길이 : 506000
# 받은 데이터 길이 : 507024
# 받은 데이터 길이 : 508048
# 받은 데이터 길이 : 509072
# 받은 데이터 길이 : 510096
# 받은 데이터 길이 : 511120
# 받은 데이터 길이 : 512144
# 받은 데이터 길이 : 513168
# 받은 데이터 길이 : 514192
# 받은 데이터 길이 : 515216
# 받은 데이터 길이 : 516240
# 받은 데이터 길이 : 517264
# 받은 데이터 길이 : 518288
# 받은 데이터 길이 : 519312
# 받은 데이터 길이 : 520336
# 받은 데이터 길이 : 521360
# 받은 데이터 길이 : 522384
# 받은 데이터 길이 : 523408
# 받은 데이터 길이 : 524432
# 받은 데이터 길이 : 525456
# 받은 데이터 길이 : 526480
# 받은 데이터 길이 : 527504
# 받은 데이터 길이 : 528528
# 받은 데이터 길이 : 529552
# 받은 데이터 길이 : 530576
# 받은 데이터 길이 : 531600
# 받은 데이터 길이 : 532624
# 받은 데이터 길이 : 533648
# 받은 데이터 길이 : 534672
# 받은 데이터 길이 : 535696
# 받은 데이터 길이 : 536720
# 받은 데이터 길이 : 537744
# 받은 데이터 길이 : 538768
# 받은 데이터 길이 : 539792
# 받은 데이터 길이 : 540816
# 받은 데이터 길이 : 541840
# 받은 데이터 길이 : 542864
# 받은 데이터 길이 : 543888
# 받은 데이터 길이 : 544912
# 받은 데이터 길이 : 545936
# 받은 데이터 길이 : 546960
# 받은 데이터 길이 : 547984
# 받은 데이터 길이 : 549008
# 받은 데이터 길이 : 550032
# 받은 데이터 길이 : 551056
# 받은 데이터 길이 : 552080
# 받은 데이터 길이 : 553104
# 받은 데이터 길이 : 554128
# 받은 데이터 길이 : 555152
# 받은 데이터 길이 : 556176
# 받은 데이터 길이 : 557200
# 받은 데이터 길이 : 558224
# 받은 데이터 길이 : 559248
# 받은 데이터 길이 : 560272
# 받은 데이터 길이 : 561296
# 받은 데이터 길이 : 562320
# 받은 데이터 길이 : 563344
# 받은 데이터 길이 : 564368
# 받은 데이터 길이 : 565392
# 받은 데이터 길이 : 566416
# 받은 데이터 길이 : 567440
# 받은 데이터 길이 : 568464
# 받은 데이터 길이 : 569488
# 받은 데이터 길이 : 570512
# 받은 데이터 길이 : 571536
# 받은 데이터 길이 : 572560
# 받은 데이터 길이 : 573584
# 받은 데이터 길이 : 574608
# 받은 데이터 길이 : 575632
# 받은 데이터 길이 : 576656
# 받은 데이터 길이 : 577680
# 받은 데이터 길이 : 578704
# 받은 데이터 길이 : 579728
# 받은 데이터 길이 : 580752
# 받은 데이터 길이 : 581776
# 받은 데이터 길이 : 582800
# 받은 데이터 길이 : 583824
# 받은 데이터 길이 : 584848
# 받은 데이터 길이 : 585872
# 받은 데이터 길이 : 586896
# 받은 데이터 길이 : 587920
# 받은 데이터 길이 : 588944
# 받은 데이터 길이 : 589968
# 받은 데이터 길이 : 590992
# 받은 데이터 길이 : 592016
# 받은 데이터 길이 : 593040
# 받은 데이터 길이 : 594064
# 받은 데이터 길이 : 595088
# 받은 데이터 길이 : 596112
# 받은 데이터 길이 : 597136
# 받은 데이터 길이 : 598160
# 받은 데이터 길이 : 599184
# 받은 데이터 길이 : 600208
# 받은 데이터 길이 : 601232
# 받은 데이터 길이 : 602256
# 받은 데이터 길이 : 603280
# 받은 데이터 길이 : 604304
# 받은 데이터 길이 : 605328
# 받은 데이터 길이 : 606352
# 받은 데이터 길이 : 607376
# 받은 데이터 길이 : 608400
# 받은 데이터 길이 : 609424
# 받은 데이터 길이 : 610448
# 받은 데이터 길이 : 611472
# 받은 데이터 길이 : 612496
# 받은 데이터 길이 : 613520
# 받은 데이터 길이 : 614544
# 받은 데이터 길이 : 615568
# 받은 데이터 길이 : 616592
# 받은 데이터 길이 : 617616
# 받은 데이터 길이 : 618640
# 받은 데이터 길이 : 619664
# 받은 데이터 길이 : 620688
# 받은 데이터 길이 : 621712
# 받은 데이터 길이 : 622736
# 받은 데이터 길이 : 623760
# 받은 데이터 길이 : 624784
# 받은 데이터 길이 : 625808
# 받은 데이터 길이 : 626832
# 받은 데이터 길이 : 627856
# 받은 데이터 길이 : 628880
# 받은 데이터 길이 : 629904
# 받은 데이터 길이 : 630928
# 받은 데이터 길이 : 631952
# 받은 데이터 길이 : 632976
# 받은 데이터 길이 : 634000
# 받은 데이터 길이 : 635024
# 받은 데이터 길이 : 636048
# 받은 데이터 길이 : 637072
# 받은 데이터 길이 : 638096
# 받은 데이터 길이 : 639120
# 받은 데이터 길이 : 640144
# 받은 데이터 길이 : 641168
# 받은 데이터 길이 : 642192
# 받은 데이터 길이 : 643216
# 받은 데이터 길이 : 644240
# 받은 데이터 길이 : 645264
# 받은 데이터 길이 : 646288
# 받은 데이터 길이 : 647312
# 받은 데이터 길이 : 648336
# 받은 데이터 길이 : 649360
# 받은 데이터 길이 : 650384
# 받은 데이터 길이 : 651408
# 받은 데이터 길이 : 652432
# 받은 데이터 길이 : 653456
# 받은 데이터 길이 : 654480
# 받은 데이터 길이 : 655504
# 받은 데이터 길이 : 656528
# 받은 데이터 길이 : 657552
# 받은 데이터 길이 : 658576
# 받은 데이터 길이 : 659600
# 받은 데이터 길이 : 660624
# 받은 데이터 길이 : 661648
# 받은 데이터 길이 : 662672
# 받은 데이터 길이 : 663696
# 받은 데이터 길이 : 664720
# 받은 데이터 길이 : 665744
# 받은 데이터 길이 : 666768
# 받은 데이터 길이 : 667792
# 받은 데이터 길이 : 668816
# 받은 데이터 길이 : 669840
# 받은 데이터 길이 : 670864
# 받은 데이터 길이 : 671888
# 받은 데이터 길이 : 672912
# 받은 데이터 길이 : 673936
# 받은 데이터 길이 : 674960
# 받은 데이터 길이 : 675984
# 받은 데이터 길이 : 677008
# 받은 데이터 길이 : 678032
# 받은 데이터 길이 : 679056
# 받은 데이터 길이 : 680080
# 받은 데이터 길이 : 681104
# 받은 데이터 길이 : 682128
# 받은 데이터 길이 : 683152
# 받은 데이터 길이 : 684176
# 받은 데이터 길이 : 685200
# 받은 데이터 길이 : 686224
# 받은 데이터 길이 : 687248
# 받은 데이터 길이 : 688272
# 받은 데이터 길이 : 689296
# 받은 데이터 길이 : 690320
# 받은 데이터 길이 : 691344
# 받은 데이터 길이 : 692368
# 받은 데이터 길이 : 693392
# 받은 데이터 길이 : 694416
# 받은 데이터 길이 : 695440
# 받은 데이터 길이 : 696464
# 받은 데이터 길이 : 697488
# 받은 데이터 길이 : 698512
# 받은 데이터 길이 : 699536
# 받은 데이터 길이 : 700416
# 파일 수신 완료 : 700416
# 파일 전송 요청을 받았습니다 server -> client
# 파일 이름 : stoc_image.jpg
# 파일 길이 : 4720
# 뿌린 메시지 : image_send_server_to_client@stoc_image.jpg@4720
# 전송중 : b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\t\x06\x07\x13\x12\x12\x15\x12\x12\x12\x12\x15\x10\x12\x15\x12\x15\x16\x10\x15\x15\x10\x15\x15\x10\x15\x15\x12\x16\x16\x15\x15\x15\x15\x18\x1d( \x18\x1a%\x1b\x15\x15!1!%)+...\x17\x1f3:3-7(9.+\x01\n\n\n\x0e\r\x0e\x1a\x10\x10\x17+\x1d\x1d\x1d-.---+-+---------+-.---------++-------------------\xff\xc0\x00\x11\x08\x00\xb4\x01\x17\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x00\x03\x00\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x04\x06\x07\x05\x03\x08\xff\xc4\x00I\x10\x00\x02\x01\x02\x03\x05\x05\x05\x03\x07\x08\n\x03\x00\x00\x00\x00\x01\x02\x03\x11\x04\x121\x05!AQa\x07\x13q\x81\x91\x06\xa1\xb1\xc1\xf0\x14"\xd1\x15#2rs\xb4\xf1BR\x82\x84\x93\xb2\xb3\xe1$%&56CTt\xc2\xd2\x1734\xff\xc4\x00\x1a\x01\x01\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\xff\xc4\x00)\x11\x01\x00\x02\x01\x03\x03\x03\x04\x02\x03\x00\x00\x00\x00\x00\x00\x00\x01\x02\x11\x03\x04!\x121A\x052Q"aq\xb1\x81\xf0#$3\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\
# 받은 데이터 길이 : 595120
# 받은 데이터 길이 : 596144
# 받은 데이터 길이 : 597168
# 받은 데이터 길이 : 598192
# 받은 데이터 길이 : 599216
# 받은 데이터 길이 : 600240
# 받은 데이터 길이 : 601264
# 받은 데이터 길이 : 602288
# 받은 데이터 길이 : 603312
# 받은 데이터 길이 : 604336
# 받은 데이터 길이 : 605360
# 받은 데이터 길이 : 606384
# 받은 데이터 길이 : 607408
# 받은 데이터 길이 : 608432
# 받은 데이터 길이 : 609456
# 받은 데이터 길이 : 610480
# 받은 데이터 길이 : 611504
# 받은 데이터 길이 : 612528
# 받은 데이터 길이 : 613552
# 받은 데이터 길이 : 614576
# 받은 데이터 길이 : 615600
# 받은 데이터 길이 : 616624
# 받은 데이터 길이 : 617648
# 받은 데이터 길이 : 618672
# 받은 데이터 길이 : 619696
# 받은 데이터 길이 : 620720
# 받은 데이터 길이 : 621744
# 받은 데이터 길이 : 622768
# 받은 데이터 길이 : 623792
# 받은 데이터 길이 : 624816
# 받은 데이터 길이 : 625840
# 받은 데이터 길이 : 626864
# 받은 데이터 길이 : 627888
# 받은 데이터 길이 : 628912
# 받은 데이터 길이 : 629936
# 받은 데이터 길이 : 630960
# 받은 데이터 길이 : 631984
# 받은 데이터 길이 : 633008
# 받은 데이터 길이 : 634032
# 받은 데이터 길이 : 635056
# 받은 데이터 길이 : 636080
# 받은 데이터 길이 : 637104
# 받은 데이터 길이 : 638128
# 받은 데이터 길이 : 639152
# 받은 데이터 길이 : 640176
# 받은 데이터 길이 : 641200
# 받은 데이터 길이 : 642224
# 받은 데이터 길이 : 643248
# 받은 데이터 길이 : 644272
# 받은 데이터 길이 : 645296
# 받은 데이터 길이 : 646320
# 받은 데이터 길이 : 647344
# 받은 데이터 길이 : 648368
# 받은 데이터 길이 : 649392
# 받은 데이터 길이 : 650416
# 받은 데이터 길이 : 651440
# 받은 데이터 길이 : 652464
# 받은 데이터 길이 : 653488
# 받은 데이터 길이 : 654512
# 받은 데이터 길이 : 655536
# 받은 데이터 길이 : 656560
# 받은 데이터 길이 : 657584
# 받은 데이터 길이 : 658608
# 받은 데이터 길이 : 659632
# 받은 데이터 길이 : 660656
# 받은 데이터 길이 : 661680
# 받은 데이터 길이 : 662704
# 받은 데이터 길이 : 663728
# 받은 데이터 길이 : 664752
# 받은 데이터 길이 : 665776
# 받은 데이터 길이 : 666800
# 받은 데이터 길이 : 667824
# 받은 데이터 길이 : 668848
# 받은 데이터 길이 : 669872
# 받은 데이터 길이 : 670896
# 받은 데이터 길이 : 671920
# 받은 데이터 길이 : 672944
# 받은 데이터 길이 : 673968
# 받은 데이터 길이 : 674992
# 받은 데이터 길이 : 676016
# 받은 데이터 길이 : 677040
# 받은 데이터 길이 : 678064
# 받은 데이터 길이 : 679088
# 받은 데이터 길이 : 680112
# 받은 데이터 길이 : 681136
# 받은 데이터 길이 : 682160
# 받은 데이터 길이 : 683184
# 받은 데이터 길이 : 684208
# 받은 데이터 길이 : 685232
# 받은 데이터 길이 : 686256
# 받은 데이터 길이 : 687280
# 받은 데이터 길이 : 688304
